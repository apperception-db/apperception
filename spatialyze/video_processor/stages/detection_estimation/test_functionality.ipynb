# %%
from segment_mapping_copy import *
import os

test_img_path = os.path.join(data_path, test_img)
test_config = fetch_camera_config(
        test_img,
        database)
test_config = camera_config(**test_config)
mapping = map_imgsegment_roadsegment(test_config)
# Out:
# ('scene-0757-CAM_FRONT', [309.1868, 668.6659, 0.0], [-0.22986569, 0.010941528, -0.023872094, -0.972868], [307.62964, 669.5079, 1.4374892], [-0.58238214, 0.61657846, 0.36259872, -0.3862437], [[1252.8131, 0.0, 826.58813], [0.0, 1252.8131, 469.98465], [0.0, 0.0, 1.0]], 876, 'samples/CAM_FRONT/n008-2018-08-30-15-16-55-0400__CAM_FRONT__1535657120612404.jpg', 63.98501, 63.39711, datetime.datetime(2018, 8, 30, 12, 25, 20, 612404, tzinfo=datetime.timezone.utc))
# total mapping time: 0.14043354988098145

# %%
len(mapping)
# Out:
# 2

# %%
visualize_single_segment(['ec17e151-b449-4bed-ad13-25197bc872fd'])
# Out:
# ec17e151-b449-4bed-ad13-25197bc872fd ['intersection', 'road']

# %%
visualization(test_img_path, test_config, mapping)
# Out:
# 82a8db53-8c9a-47b4-84a5-ba0d1aee2e46 lanegroup0
# 3d8e2040-aa79-4080-b496-567236e8b3df road1
